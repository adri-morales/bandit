# %% [markdown]
# # Results Analysis

# %% [markdown]
# ### Imports

# %%
import os

import seaborn as sns
import matplotlib.pyplot as plt

import pandas as pd

# %% [markdown]
# ## Load data

# %%
df = pd.read_csv('../data/results/history.csv', index_col=0)

# %%
df.head()
# Out:
#    episode  step    reward  action
# 0        0     0 -1.932798       4
# 1        0     1 -0.057185       4
# 2        0     2  1.521098       4
# 3        0     3  0.450935       4
# 4        0     4  0.064038       4

# %%
sns.lineplot(data=df, x='step', y='reward')
# Out:
# <Axes: xlabel='step', ylabel='reward'>
