# %% [markdown]
# # Results Analysis

# %% [markdown]
# ### Imports

# %%
import os

import seaborn as sns
import matplotlib.pyplot as plt

import pandas as pd
from glob import glob

# %% [markdown]
# ## Load data

# %%
df_list = []
for history in glob('../data/results/*.csv'):
    df = pd.read_csv(history, index_col=0)
    df_list.append(df)

# %%
df = pd.concat(df_list)

# %%
df.head()
# Out:
#    episode  step    reward  action   agent
# 0        0     0 -3.507078       9  greedy
# 1        0     1 -0.266085       9  greedy
# 2        0     2  0.441611       9  greedy
# 3        0     3 -1.061337       9  greedy
# 4        0     4  2.349000       6  greedy

# %%
df = pd.DataFrame(df.groupby(['step', 'agent']).reward.mean()).reset_index()

# %%
sns.lineplot(data=df, x='step', y='reward', hue='agent')
plt.show()
